# %%
"""
TenderBot 1.0 - Casca Kwok

The bot is built in an aim to automate TCP/IP networking tendor response process, to enhance efficiency
from searching tendor parameters, just by input network equipment model into a list to save hours of effort!

TenderBot 1.0 supports information returned by .html format

"""
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import requests
import pandas as pd
import re
from re import search
import matplotlib.pyplot as plt
import numpy as np
import math
from IPython.display import display

"""
Part 1 : Obtain Cisco datasheet to obtain MTBF figure

- Web scrap MTBF figure for dataset.
    - make a google search with network equipment model name + "MTBF" as keywords
    - Take the first link returned by google
    - Download the page and search for MTBF keywords
    - print out MTBF for each network equipment
"""
#---- Part 1 : Obtain Cisco datasheet to obtain MTBF figure ------------------------------------
class Equipment: #Create objects to hold datasheet url, MTBF

    def __init__(self, equipment_model):
        self.model = equipment_model

    def DatasheetUrl(self): #function assigning datasheet url of a network equipment

        SearchString = self.model.replace(" ", "+") + "+mtbf"
        print ("Search keywords: ", SearchString)

        url1 = "https://www.google.com/search?q=" + SearchString
        req = Request(url1, headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urlopen(req).read()
        equipment1_google = BeautifulSoup(webpage, "html.parser")
        links = equipment1_google.findAll("a", href=True)
        links2 = equipment1_google.findAll("h3")

        for items in links: #get the first url from google search result
            if (links2[0]) in items:
                result = items
                result_href = str(items.get('href'))

        try: #.html is the supported format.  .pdf might be for next version.
            result_split = result_href.replace("/url?q=", '')
            test = ".html"
            result_split = result_split[:result_split.index(test) + 5]
            print("Search Result: ", result_split, "\n")
            print("-".center(100, "-"))
            return result_split
        except:
            print ("Non .html is not supported.")
            return "None"


    def MtbfTable(self):

        url = self.DatasheetUrl()

        if url == "None":
          return
          
        try:            #if the returned .html has "MTBF" in table
            df = pd.read_html(url, index_col=0, match='MTBF')
            return df
        except:         #else if the returned .html has no table, search by text
            req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
            webpage = urlopen(req).read()
            QnA = BeautifulSoup(webpage, "html.parser")

            #soup.body.findAll(text=re.compile('^Python$'))

            mtbf = QnA.body.findAll(text=re.compile('MTBF'))

            Neat_text = ""

            for items in mtbf:
                Neat_text = Neat_text + items
            return Neat_text

#Declare a list to look up desired network equipment's MTBF
inventory = ["Cisco 9400 C9400-SUP-1XL-Y", "Cisco Catalyst 9600 Series Supervisor Engine 1", "Cisco 9800-80",
             "Cisco Nexus 9500", "Cisco NCS 5500", "Cisco IE4000"]
Cisco = {}

#automatically create objects when there is change in the list inventory
for i in range(0, len(inventory), 1):
    Cisco[i] = Equipment(inventory[i])
    print("-".center(100, "-"))
    print(Cisco[i].model.center(100), "\n", "\n")
    print("MTBF: " + "\n\n" + str(Cisco[i].MtbfTable()))
# Out:
# ----------------------------------------------------------------------------------------------------
#                                      Cisco 9400 C9400-SUP-1XL-Y
#
#
# Search keywords:  Cisco+9400+C9400-SUP-1XL-Y+mtbf
# Search Result:  https://www.cisco.com/c/en/us/products/collateral/switches/catalyst-9400-series-switches/nb-06-cat9400-series-line-data-sheet-cte-en.html
#
# ----------------------------------------------------------------------------------------------------
# MTBF:
#
# [               Max rated power (W)  Rated MTBF (hours)
# Part number
# C9400-LC-48HX                  270                 NaN
# C9400-LC-48HN                  175                 NaN
# C9400-LC-48H                    65            874140.0
# C9400-LC-48U                    65            915150.0
# C9400-LC-48T                    65           1214080.0
# C9400-LC-48XS                  250                 NaN
# C9400-LC-24XS                  200            545080.0
# C9400-LC-48UX                  240            469550.0
# C9400-LC-48P                    65            980440.0
# C9400-LC-24S                   120           1104470.0
# C9400-LC-48S                   170            937600.0,                                                  Sustainability Topic.1  \
# Sustainability Topic
# General               Information on product-material-content laws a...
# General               Information on electronic waste laws and regul...
# General                                        Sustainability Inquiries
# General               Information on product takeback and resuse pro...
# General                              Environmental Operating Conditions
# General                                       Regulatory and compliance
# General                       Mean Time Between Failures – MTBF (hours)
# General               Cisco Enhanced Limited Lifetime Hardware Warranty
# Power                                                             Power
# Material                         Product packaging weight and materials
# Material                                            Physical Dimensions
#
#                                                 Reference  \
# Sustainability Topic
# General                                         Materials
# General                                   WEEE Compliance
# General                  Contact: csr_inquiries@cisco.com
# General                  Cisco Takeback and Reuse Program
# General                   Table 2: Product specifications
# General                   Table 2: Product specifications
# General               Table 3: Power and MTBF information
# General                            Table 5: E-LLW details
# Power                 Table 3: Power and MTBF information
# Material                   Contact: environment@cisco.com
# Material                  Table 2: Product specifications
#
#                                            Reference.1
# Sustainability Topic
# General                                      Materials
# General                                WEEE Compliance
# General               Contact: csr_inquiries@cisco.com
# General               Cisco Takeback and Reuse Program
# General                Table 2: Product specifications
# General                                            NaN
# General                                            NaN
# General                                            NaN
# Power                                              NaN
# Material                                           NaN
# Material                                           NaN  ]
# ----------------------------------------------------------------------------------------------------
#                            Cisco Catalyst 9600 Series Supervisor Engine 1
#
#
# Search keywords:  Cisco+Catalyst+9600+Series+Supervisor+Engine+1+mtbf
# Search Result:  https://www.cisco.com/c/en/us/products/collateral/switches/catalyst-9600-series-switches/nb-06-cat9600-series-data-sheet-cte-en.html
#
# ----------------------------------------------------------------------------------------------------
# MTBF:
#
# [                                                                                       Specifications
# Description
# SKU                                                                                            C9606R
# Dimensions (H x W x D)                                 35.43 x 44.2 x 40.9 cm 13.95 x 17.4 x 16.1 in.
# Rack Units (RU)                                                                                     8
# Chassis Weight with 2 Power Supplies (AC) and F...                                31.31 kg (69.03 lb)
# Input Voltage                                        AC: 90V to 264V, 47 to 63 Hz AC DC: -40V to -72V
# Operating Temperature                               -5° to 45° C (23° to 113° F) up to 6000 feet -...
# Storage Temperature                                                     -40° to 75° C (40° to 167° F)
# Relative Humidity, Operating and Non-operating,...                         10% to 95%, Non-condensing
# Altitude                                                            -60 to 3000 m (-197 to 9843 feet)
# Mean Time Between Failures (MTBF) (hours)           C9606R chassis: 4,113,900 C9606 fan tray: 452,...
# Chassis Weight (without Fan tray, without PSU)                                    25.36 kg (55.90 lb)
# Weight of Fan-tray                                                                  3.56 kg (7.85 lb)
# Weight of individual PSUs                           AC PSU: 1.2 kg (2.65 lb) DC PSU: 1.28 kg (2.82...,                                                               Reference  \
# Sustainability Topic
# General               Information on product-material-content laws a...
# General               Information on electronic waste laws and regul...
# General                                        Sustainability Inquiries
# General               Information on product takeback and reuse program
# General                                           Safety and compliance
# General                       Mean Time Between Failures – MTBF (hours)
# Power                                           Default AC power supply
# Power                                                    Power supplies
# Power                                                    Power supplies
# Power                                                    Power supplies
# Power                                                               Fan
# Power                                         Energy Efficient Ethernet
# Power                            Product packaging weight and materials
# Power                                                        Dimensions
# Material                                                         Weight
# Material                      Elimination of wet paint on plastic bezel
#
#                                                              Unnamed: 2
# Sustainability Topic
# General                                                       Materials
# General                                                 WEEE Compliance
# General                                Contact: csr_inquiries@cisco.com
# General                                Cisco Takeback and Reuse Program
# General                     Table 16. Safety and compliance information
# General               Table.24 Model Dimensions, Weight, and Mean Ti...
# Power                                                  Platform details
# Power                           Table 11: Power output in combined mode
# Power                                Table 11: Power Output in N+1 Mode
# Power                             Table 13: Power Supply Specifications
# Power                                                Table 14. Fan tray
# Power                                                   Smart operation
# Power                                    Contact: environment@cisco.com
# Power                 Table 10: Physical specifications of Cisco Cat...
# Material              Table 10: Physical specifications of Cisco Cat...
# Material              2019 Cisco Corporate Social Responsibility Rep...  ]
# ----------------------------------------------------------------------------------------------------
#                                            Cisco 9800-80
#
#
# Search keywords:  Cisco+9800-80+mtbf
# Search Result:  https://www.cisco.com/c/en/us/products/collateral/wireless/catalyst-9800-series-wireless-controllers/nb-06-cat9800-ser-wirel-faq-ctp-en.html
#
# ----------------------------------------------------------------------------------------------------
# MTBF:
#
# What is the Mean Time Between Failures (MTBF) for the 9800-L, 9800-40, and 9800-80 wireless controllers?
#    MTBF for C9800-L is 100,000 hours
#
#      MTBF for C9800-40 is 123,450 hours
#
#      MTBF for C9800-80 is 85,450 hours
#
# ----------------------------------------------------------------------------------------------------
#                                           Cisco Nexus 9500
#
#
# Search keywords:  Cisco+Nexus+9500+mtbf
# Search Result:  https://www.cisco.com/c/en/us/products/collateral/switches/nexus-9000-series-switches/datasheet-c78-729404.html
#
# ----------------------------------------------------------------------------------------------------
# MTBF:
#
# [                                                                                              Benefit
# Feature
# High performance                                    The Cisco Nexus 9500 Series switch delivers no...
# Telemetry                                           The Cisco Nexus 9500 Series switches support e...
# High-density 1-, 10-, 25-, 40- and 50-Gigabit E...  Organizations can transition from low-speed (1...
# High-density 10-, 40-, 100- and 400-Gigabit Eth...  The Cisco Nexus 9500 Series Switches help orga...
# High availability, reliability, and scalability     The Cisco Nexus 9500 Series Switches are desig...
# Designed for the future                             The Cisco Nexus 9500 Series Switches are desig...
# Power efficiency                                    The Cisco Nexus 9500 Series Switches are the f...,                                                                  Cisco Nexus 9504 Chassis  \
# Number of line card slots                                                               4
# Dimensions (H x W x D)                  12.25 x 17.50 x 33.15 in. (31.1 x 44.50 x 84.2...
# Weight                                                                    84 lb (38.2 kg)
# Rack Units                                                                              7
# Mean Time Between Failure (MTBF) Hours                                            1038080
# Operating temperature                                             32 to 104°F (0 to 40°C)
# Nonoperating temperature                                       -40 to 158°F (-40 to 70°C)
# Humidity                                                         5 to 95% (noncondensing)
# Altitude                                                     0 to 13,123 ft (0 to 4,000m)
# Regulatory compliance                   Products should comply with CE Markings accord...
# Safety                                  UL 60950-1 Second Edition CAN/CSA-C22.2 No. 60...
# EMC: Emissions                          47CFR Part 15 (CFR 47) Class A AS/NZS CISPR22 ...
# EMC: Immunity                                  EN55024 CISPR24 EN300386 KN 61000-4 series
# RoHS                                    The product is RoHS-6 compliant with exception...
#
#                                                                  Cisco Nexus 9508 Chassis  \
# Number of line card slots                                                               8
# Dimensions (H x W x D)                  22.70 x 17.50 x 31.76 in. (57.78 x 44.50 x 80....
# Weight                                                                   150 lb (68.2 kg)
# Rack Units                                                                             13
# Mean Time Between Failure (MTBF) Hours                                             928910
# Operating temperature                                             32 to 104°F (0 to 40°C)
# Nonoperating temperature                                       -40 to 158°F (-40 to 70°C)
# Humidity                                                         5 to 95% (noncondensing)
# Altitude                                                     0 to 13,123 ft (0 to 4,000m)
# Regulatory compliance                   Products should comply with CE Markings accord...
# Safety                                  UL 60950-1 Second Edition CAN/CSA-C22.2 No. 60...
# EMC: Emissions                          47CFR Part 15 (CFR 47) Class A AS/NZS CISPR22 ...
# EMC: Immunity                                  EN55024 CISPR24 EN300386 KN 61000-4 series
# RoHS                                    The product is RoHS-6 compliant with exception...
#
#                                                                  Cisco Nexus 9516 Chassis
# Number of line card slots                                                              16
# Dimensions (H x W x D)                  36.70 x 17.50 x 31.76 in. (93.41 x 44.50 x 80....
# Weight                                                                   192 lb (87.3 kg)
# Rack Units                                                                             21
# Mean Time Between Failure (MTBF) Hours                                             680000
# Operating temperature                                             32 to 104°F (0 to 40°C)
# Nonoperating temperature                                       -40 to 158°F (-40 to 70°C)
# Humidity                                                         5 to 95% (noncondensing)
# Altitude                                                     0 to 13,123 ft (0 to 4,000m)
# Regulatory compliance                   Products should comply with CE Markings accord...
# Safety                                  UL 60950-1 Second Edition CAN/CSA-C22.2 No. 60...
# EMC: Emissions                          47CFR Part 15 (CFR 47) Class A AS/NZS CISPR22 ...
# EMC: Immunity                                  EN55024 CISPR24 EN300386 KN 61000-4 series
# RoHS                                    The product is RoHS-6 compliant with exception...  ,                                  N9K-SUP-A                   N9K-SUP-A+  \
# Processor      4 core, 4 thread 1.8GHz x86  4 core, 8 thread 1.8GHz x86
# DRAM                                  16GB                         16GB
# SSD                                   64GB                         64GB
# Weight                    4.84 lb (2.2 kg)             5.2 lb (2.37 kg)
# Typical power                         69 W                         69 W
# Maximum power                         80 W                         80 W
# MTBF hours                          312070                       414240
# Hot swappable                          Yes                          Yes
# Airflow                   Port-side intake             Port-side intake
#
#                                   N9K-SUP-B                    N9K-SUP-B+
# Processor      6 core, 12 thread 2.2GHz x86  6 core, 12 thread 1.9GHz X86
# DRAM                                   24GB                          32GB
# SSD                                   256GB                         256GB
# Weight                    6.00 lb (2.72 kg)              5.3 lb (2.39 kg)
# Typical power                          75 W                          75 W
# Maximum power                          80 W                          90 W
# MTBF hours                           292110                        421040
# Hot swappable                           Yes                           Yes
# Airflow                    Port-side intake              Port-side intake  ,                        N9K-SC-A
# Weight         1.91 lb (0.9 kg)
# Typical power              14 W
# Maximum power              25 W
# MTBF hours              1380210
# Hot swappable               Yes
# Airflow        Port-side intake,                  Cisco Nexus 9500 3000W AC Power Supply  \
# Output power                                     3000 W
# Input voltage                          AC: 200V to 240V
# Number of inputs                                      1
# Frequency                                   50 to 60 Hz
# Efficiency                              80PLUS Platinum
# Weight                                  6.2 lb (2.8 kg)
# MTBF hours                                       868870
# Hot swappable                                       Yes
# Airflow                                             Yes
#
#                              Cisco Nexus 9500 3000W DC Power Supply  \
# Output power                                                 3000 W
# Input voltage     DC: -48V to -60V (nominal) -40V to -72V (min –...
# Number of inputs                        2 (1500 W output per input)
# Frequency                                                       NaN
# Efficiency                               80PLUS Platinum Equivalent
# Weight                                              6.4 lb (2.9 kg)
# MTBF hours                                                  1761580
# Hot swappable                                                   Yes
# Airflow                                                         Yes
#
#                        Cisco Nexus 9500 3000W HV AC/DC Power Supply  \
# Output power                                                 3000 W
# Input voltage     AC: 200V to 277V DC: 240V to 380V (nominal) 19...
# Number of inputs                                                  1
# Frequency                                   AC: 47 to 63 Hz DC: N/A
# Efficiency        80PLUS Platinum (AC) 80PLUS Platinum Equivalen...
# Weight                                             5.9 lb (2. 7 kg)
# MTBF hours                                                   965700
# Hot swappable                                                   Yes
# Airflow                                                         Yes
#
#                        Cisco Nexus 9500 3150W HV AC/DC Power Supply
# Output power                                                 3150 W
# Input voltage     AC: 200V to 277V DC: 240V to 380V (nominal) 19...
# Number of inputs                        2 (3150 W output per input)
# Frequency                                   AC: 47 to 63 Hz DC: N/A
# Efficiency        80PLUS Titanium (AC) 80PLUS Titanium Equivalen...
# Weight                                              9.9 lb (4.5 kg)
# MTBF hours                                                   838900
# Hot swappable                                                   Yes
# Airflow                                                         Yes  ]
# ----------------------------------------------------------------------------------------------------
#                                            Cisco NCS 5500
#
#
# Search keywords:  Cisco+NCS+5500+mtbf
# Search Result:  https://www.cisco.com/c/en/us/products/collateral/routers/network-convergence-system-5500-series/datasheet-c78-741080.html
#
# ----------------------------------------------------------------------------------------------------
# MTBF:
#
# [                                                 Sustainability Topic.1  \
# Sustainability Topic
# General               Information on product-material-content laws a...
# General               Information on electronic waste laws and regul...
# General               Information on product takeback and resuse pro...
# General                                        Sustainability Inquiries
# General                                 Countries and Regions Supported
# General                             Predicted MTBF of Chassis (at 40°C)
# General                             Predicted MTBF of Chassis (at 40°C)
# General                             Predicted MTBF of Chassis (at 40°C)
# General                             Predicted MTBF of Chassis (at 40°C)
# General                             Predicted MTBF of Chassis (at 40°C)
# General                                 Predicted MTBF of MPA (at 40°C)
# General                                 Predicted MTBF of MPA (at 40°C)
# General                                 Predicted MTBF of MPA (at 40°C)
# General                                 Predicted MTBF of MPA (at 40°C)
# General                                 Predicted MTBF of MPA (at 40°C)
# General                                 Predicted MTBF of MPA (at 40°C)
# General                                 Predicted MTBF of MPA (at 40°C)
# Power                                                 Power consumption
# Material                         Product packaging weight and materials
# Material                                                         Weight
#
#                                                           Reference  \
# Sustainability Topic
# General                                                   Materials
# General                                             WEEE Compliance
# General                            Cisco Takeback and Reuse Program
# General                            Contact: csr_inquiries@cisco.com
# General                                         Table 6 and Table 7
# General                                              NCS-55A2-MOD-S
# General                                           NCS-55A2-MOD-HD-S
# General                                           NCS-55A2-MOD-HX-S
# General                                           NCS-55A2-MOD-SE-S
# General                                           NC55A2-MOD-SE-H-S
# General                                               NC55-MPA-4H-S
# General                                            NC55-MPA-4H-HX-S
# General                                            NC55-MPA-4H-HD-S
# General                                              NC55-MPA-2TH-S
# General                                           NC55-MPA-2TH-HX-S
# General                                            NC55-MPA-1TH2H-S
# General                                              NC55-MPA-12T-S
# Power                 Table 2: Cisco NCS 55A2 Chassis specification
# Material                             Contact: environment@cisco.com
# Material              Table 2: Cisco NCS 55A2 Chassis specification
#
#                                                         Reference.1
# Sustainability Topic
# General                                                   Materials
# General                                             WEEE Compliance
# General                            Cisco Takeback and Reuse Program
# General                            Contact: csr_inquiries@cisco.com
# General                                         Table 6 and Table 7
# General                                               255,590 hours
# General                                               226,770 hours
# General                                               221,010 hours
# General                                               236,200 hours
# General                                               214,920 hours
# General                                             3,343,850 hours
# General                                             3,392,930 hours
# General                                             3,392,970 hours
# General                                             3,332,150 hours
# General                                             3,380,920 hours
# General                                             3,329,000 hours
# General                                             2,587,960 hours
# Power                 Table 2: Cisco NCS 55A2 Chassis specification
# Material                             Contact: environment@cisco.com
# Material              Table 2: Cisco NCS 55A2 Chassis specification  ]
# ----------------------------------------------------------------------------------------------------
#                                             Cisco IE4000
#
#
# Search keywords:  Cisco+IE4000+mtbf
# Search Result:  https://www.cisco.com/c/en/us/products/collateral/switches/industrial-ethernet-4000-series-switches/datasheet-c78-733058.html
#
# ----------------------------------------------------------------------------------------------------
# MTBF:
#
# [                                                                             Standards
# Type
# Electromagnetic emissions            FCC 47 CFR Part 15 Class A EN 55022A Class A E...
# Electromagnetic immunity             EN55024 CISPR 24 AS/NZS CISPR 24 KN24 EN 61000...
# Industry standards                   EN 61000-6-1 Light Industrial EN 61000-6-2 Ind...
# Safety standards and certifications  Information Technology Equipment: UL/CSA 60950...
# Operating environment                Operating Temperature: -40C to +75C ● -40C to ...
# Storage environment                  Temperature: -40 to +85 degrees C Altitude: 15...
# Humidity                             Relative humidity of 5% to 95% non-condensing ...
# Shock and vibration                  IEC 60068-2-27 (operational shock, 50G, 11ms, ...
# Corrosion                            ISO 9223: Corrosion class C3-Medium class C4-H...
# Others                               RoHS Compliance China RoHS Compliance TAA (Gov...
# Warranty                             Five-year limited HW warranty on all IE-4000 P...
# Mean Time Between Failures (MTBF)    IE-4000-4TC4G-E: 578, 730 Hours IE-4000-8T4G-E...]
